# %% [markdown]
# # 이변량_숫자 vs 숫자

# %% [markdown]
# * 우리가 사용하는 도구는...
#     * 두 변수와의 관계를 살펴보기 위해, 두가지 도구(시각화, 수치화)를 이용합니다.
#     * 이 도구들도 각각 한계가 있습니다. 보이는게 전부가 아님을 꼭 명심하세요!
#     * 특히 수치화 도구(가설검정 도구)는 많은 가정들이 전제 됩니다.
#     * 그래서 이번 과정에서는 그 도구를 사용하는 데에 집중합니다.

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# * 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * 데이터 불러오기 : 다음의 예제 데이터를 사용합니다.
# > ① 타이타닉 생존자
# ② 뉴욕 공기 오염도

# %%
# 타이타닉 데이터
titanic = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic.0.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 뉴욕시 공기 오염도 데이터
air = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/air2.csv')
air['Date'] = pd.to_datetime(air['Date'])
# air['Month'] = air.Date.dt.month
# air['Weekday'] = air.Date.dt.weekday
air.head()
# Out:
#    Ozone  Solar.R  Wind  Temp       Date
# 0     41    190.0   7.4    67 1973-05-01
# 1     36    118.0   8.0    72 1973-05-02
# 2     12    149.0  12.6    74 1973-05-03
# 3     18    313.0  11.5    62 1973-05-04
# 4     19      NaN  14.3    56 1973-05-05

# %% [markdown]
# ----

# %% [markdown]
# ## 2.시각화 : 산점도

# %% [markdown]
# * 상관 분석에 대해서 이야기 해봅시다.
#     * 상관 분석은 연속형 변수 X에 대한 연속형 변수 Y의 관계를 분석할 때 사용됩니다.
#     * Scatter를 통해 시각화 합니다.
# * 가설 : 온도(x)가 상승하면 아이스크림 판매량(y)을 증가할까?
#     * 어떤 관계가 보이나요?
#     * 얼마나 강한 관계인가요?
# * 숫자 vs 숫자를 비교할 때 중요한 관점이 **‘직선’ (Linearity)**입니다.

# %% [markdown]
# <img src='https://github.com/DA4BAM/image/blob/main/%EC%82%B0%EC%A0%90%EB%8F%84_ex.png?raw=true' width=500/>

# %% [markdown]
# ### (1) 산점도

# %% [markdown]
# * 문법
#     * plt.scatter( x축 값, y축 값 )
#     * plt.scatter( ‘x변수’, ‘y변수’, data = dataframe이름)

# %%
plt.scatter(air['Temp'], air['Ozone'])
plt.show()

# %%
plt.scatter('Temp', 'Ozone', data = air)
plt.show()

# %%
sns.scatterplot(x='Temp', y='Ozone', data = air)
plt.show()

# %% [markdown]
# 그래프를 그렸으면, 그래프로부터 정보를 파악해야 합니다.
#
# 무엇이 보이나요?

# %% [markdown]
#     온도가 높으면 오존이 대체적으로 높다.

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# * [문1] Temp, Wind, Solar.R 과 Ozone 과의 관계를 시각화 해 봅시다.

# %%
plt.figure(figsize = (12, 4))

plt.subplot(1, 3, 1)
sns.scatterplot(x = 'Temp', y = 'Ozone', data = air)
plt.grid()

plt.subplot(1, 3, 2)
sns.scatterplot(x = 'Wind', y = 'Ozone', data = air)
plt.grid()

plt.subplot(1, 3, 3)
sns.scatterplot(x = 'Solar.R', y = 'Ozone', data = air)
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# * [문2] Ozone과 가장 강한 관계의 x변수는?

# %% [markdown]
# * 두 변수의 관계
#     * 산점도에서 또렷한 패턴이 보인다면, 강한 관계로 볼 수 있습니다.
#     * 특히, 직선의 패턴이 보인다면

# %% [markdown]
# <img src='https://cqeacademy.com/wp-content/uploads/2018/06/Scatter-Plots-and-Correlation-Examples.png' width=800/>

# %% [markdown]
# ### (2) pairplot으로 한꺼번에 시각화 할 수 있습니다.
#
# * 숫자형 변수들에 대한 산점도를 한꺼번에 그려줍니다.
# * 그러나 **시간이 많이**걸립니다.

# %%
sns.pairplot(air)
plt.show()

# %% [markdown]
# ###  (3) (추가) jointplot 로 살펴보기
#
# * jointplot은 산점도와 각각의 히스토그램을 함께 보여줍니다.

# %% [markdown]
# * Temp --> Ozone

# %%
sns.jointplot(x='Temp', y='Ozone', data = air)
plt.show()

# %% [markdown]
# * Wind --> Ozone

# %%
sns.jointplot(x='Wind', y='Ozone', data = air)
plt.show()

# %% [markdown]
# * Solar.R --> Ozone

# %%
sns.jointplot(x='Solar.R', y='Ozone', data = air)
plt.show()

# %%
# 산점도의 회귀선도 plot
sns.regplot(x='Solar.R', y='Ozone', data = air)
plt.show()

# %% [markdown]
# ## 3.수치화 : 상관분석

# %% [markdown]
# ### (1) 상관계수, p-value

# %% [markdown]
# * 상관계수 𝑟
#     * 공분산을 표준화 한 값
#     * -1 ~ 1 사이의 값
#     * -1, 1에 가까울 수록 강한 상관관계를 나타냄.
#
# * 경험에 의한 대략의 기준(절대적인 기준이 절대 아닙니다.)
#     * 강한 : 0.5 < |𝑟| ≤ 1
#     * 중간 : 0.2 < |𝑟| ≤ 0.5
#     * 약한 : 0.1 < |𝑟| ≤ 0.2
#     * (거의)없음 : |𝑟| ≤ 0.1

# %%
import scipy.stats as spst

# %%
# 상관계수와 p-value 
spst.pearsonr(air['Temp'], air['Ozone'])
# Out:
# PearsonRResult(statistic=0.6833717861490114, pvalue=2.197769800200274e-22)

# %% [markdown]
# 결과는 튜플로 나오는데
#
# 1. 튜플의 첫 번째 값 : 상관계수를 뜻합니다.
# 2. 두번째 값 : p-value
#     * 귀무가설 : 상관 관계가 없다.(상관계수가 0이다.)
#     * 대립가설 : 상관 관계가 있다.(상관계수가 0이 아니다.)
# 3. 주의 사항 : 값에 NaN이 있으면 계산되지 않습니다. 반드시 .notnull()로 제외하고 수행해야 합니다.

# %% [markdown]
# ### (2) 데이터프레임 한꺼번에 상관계수 구하기

# %%
# 데이터프레임으로 부터 수치형 데이터에 대한 상관계수 구하기
air.corr()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2212\1676378197.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   air.corr()
#             Ozone   Solar.R      Wind      Temp
# Ozone    1.000000  0.280068 -0.605478  0.683372
# Solar.R  0.280068  1.000000 -0.056792  0.275840
# Wind    -0.605478 -0.056792  1.000000 -0.457988
# Temp     0.683372  0.275840 -0.457988  1.000000

# %% [markdown]
# 위 결과로 부터,
# 1. 같은 변수끼리 구한 값 1은 의미 없다.
# 2. 상관계수의 절대값이
#     * 1에 가까울 수록 강한 상관관계
#     * 0에 가까울 수록 약한 상관관계
# 3. +는 양의 상관관계, -는 음의 상관관계

# %% [markdown]
# ### (3) (추가) 상관계수를 heatmap으로 시각화

# %%
plt.figure(figsize = (8, 8))
sns.heatmap(air.corr(), 
            annot = True,            # 숫자(상관계수) 표기 여부
            fmt = '.3f',             # 숫자 포멧 : 소수점 3자리까지 표기
            cmap = 'RdYlBu_r',       # 칼라맵
            vmin = -1, vmax = 1)     # 값의 최소, 최대값값
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2212\597608571.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(air.corr(),

# %% [markdown]
# 칼라를 변경하려면 아래 링크로 가서 color map 을 확인하고 조정하세요.
# cmap(color map) : https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# * 다음의 변수에 대해서 상관분석을 수행하시오.

# %% [markdown]
# * [문1] Temp --> Ozone

# %%
spst.pearsonr(air['Temp'], air['Ozone'])
# Out:
# PearsonRResult(statistic=0.6833717861490114, pvalue=2.197769800200274e-22)

# %% [markdown]
# * [문2] Wind --> Ozone

# %%
spst.pearsonr(air['Wind'], air['Ozone'])
# Out:
# PearsonRResult(statistic=-0.6054782354684075, pvalue=1.1255146087638192e-16)

# %% [markdown]
# * [문3] Solar.R --> Ozone
#     * 단, Solar.R 에는 NaN이 있습니다. NaN을 제외(.notnull())하고, 상관분석을 수행하시오.

# %%
tmp = air.loc[air['Solar.R'].notnull()]
spst.pearsonr(tmp['Solar.R'], tmp['Ozone'])
# Out:
# PearsonRResult(statistic=0.2800681334905377, pvalue=0.0006175878788566531)

# %%
# NAN 찾기
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    153 non-null    int64
#  1   Solar.R  146 non-null    float64
#  2   Wind     153 non-null    float64
#  3   Temp     153 non-null    int64
#  4   Date     153 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 6.1 KB

# %%
air.isna().sum()
# Out:
# Ozone      0
# Solar.R    7
# Wind       0
# Temp       0
# Date       0
# dtype: int64

# %% [markdown]
# ## 4.복습문제

# %% [markdown]
# * 보스톤 집값 데이터를 이용하여 다음의 복습문제를 풀어 봅시다.

# %% [markdown]
# **변수설명**
# > * medv  : 1978 보스턴 주택 가격, 506개 타운의 주택 가격 중앙값 (단위 1,000 달러) <== Target
# * crim	범죄율
# * zn	25,000 평방피트를 초과 거주지역 비율
# * indus	비소매상업지역 면적 비율
# * chas	찰스강변 위치(범주 : 강변1, 아니면 0)
# * nox	일산화질소 농도
# * rm	주택당 방 수
# * age	1940년 이전에 건축된 주택의 비율
# * dis	직업센터의 거리
# * rad	방사형 고속도로까지의 거리
# * tax	재산세율
# * ptratio	학생/교사 비율
# * lstat	인구 중 하위 계층 비율

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as spst

# %%
# 보스톤 집값 데이터
boston = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/boston.csv')
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %% [markdown]
# * 1) crim(범죄율) --> mdev(집값) 에 대해 시각화와 수치화(상관분석)을 수행후 관계를 평가하시오.

# %%
# boston.info()

# %%
# boston.isna().sum()

# %%
sns.scatterplot(x = 'crim', y = 'medv', data = boston)
plt.grid()
plt.show()

# %%
print(spst.pearsonr(boston['crim'], boston['medv']))

# display(boston.corr())
# Out:
# PearsonRResult(statistic=-0.3883046085868116, pvalue=1.1739870821941207e-19)

# %% [markdown]
#     상관계수가 |r| = 0.388로 중간 정도의 상관 관계가 존재하고
#     p_value는 0에 수렴하기 때문에 'crim'과 'medv"는 서로 관계가 있다고 판단 할 수 있다.

# %%
# sns.pairplot(boston)

# %%
# tmp.loc[:, ['crim', 'medv']]

# %% [markdown]
# * 2) tax(제산세율) --> mdev(집값) 에 대해 시각화와 수치화(상관분석)을 수행후 관계를 평가하시오.

# %%
plt.figure(figsize= (3, 2))
sns.scatterplot(x = 'tax', y = 'medv', data = boston)
plt.grid()
plt.show()

print(spst.pearsonr(boston['tax'], boston['medv']))
# Out:
# PearsonRResult(statistic=-0.4685359335677671, pvalue=5.637733627689083e-29)

# %% [markdown]
#     상관계수 |r| = 0.469로 중간 정도의 상관관계가 있고,
#     p_value는 0에 수렴하기 때문에 'tax'와 'medv'는 서로 관계가 있다고 판단 할 수 있다.

# %% [markdown]
# * 3) lstat(하위계층비율) --> mdev(집값) 에 대해 시각화와 수치화(상관분석)을 수행후 관계를 평가하시오.

# %%
plt.figure(figsize= (3, 2))
sns.scatterplot(x = 'lstat', y = 'medv', data = boston)
plt.grid()
plt.show()

print(spst.pearsonr(boston['lstat'], boston['medv']))
# Out:
# PearsonRResult(statistic=-0.7376627261740148, pvalue=5.08110339438697e-88)

# %% [markdown]
#     상관계수 |r| = 0.738로 강한 상관관계가 있고,
#     p_value는 0으로 수렴하기 때문에, 'lstat'

# %% [markdown]
# * 4) 전체 변수들끼리의 상관계수를 구하고, 가장 강한 상관관계와 가장 약한 상관관계를 찾아 봅시다.

# %%
tmp = boston.corr()
display(tmp)
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
# tmp_max = tmp.loc[tmp['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat', 'medv'] != 0]
tmp2 = tmp.abs()
tmp_max, tmp_max2 = [], []
tmp_min, tmp_min2 = [], []

tmp_max.append(tmp2.loc[tmp2['crim'] != 1, 'crim'].max())
tmp_min.append(tmp2.loc[tmp2['crim'] != 1, 'crim'].min())

tmp_max.append(tmp2.loc[tmp2['zn'] != 1, 'zn'].max())
tmp_min.append(tmp2.loc[tmp2['zn'] != 1, 'zn'].min())

tmp_max.append(tmp2.loc[tmp2['indus'] != 1, 'indus'].max())
tmp_min.append(tmp2.loc[tmp2['indus'] != 1, 'indus'].min())

tmp_max.append(tmp2.loc[tmp2['chas'] != 1, 'chas'].max())
tmp_min.append(tmp2.loc[tmp2['chas'] != 1, 'chas'].min())

tmp_max.append(tmp2.loc[tmp2['nox'] != 1, 'nox'].max())
tmp_min.append(tmp2.loc[tmp2['nox'] != 1, 'nox'].min())

tmp_max.append(tmp2.loc[tmp2['rm'] != 1, 'rm'].max())
tmp_min.append(tmp2.loc[tmp2['rm'] != 1, 'rm'].min())

tmp_max.append(tmp2.loc[tmp2['age'] != 1, 'age'].max())
tmp_min.append(tmp2.loc[tmp2['age'] != 1, 'age'].min())

tmp_max.append(tmp2.loc[tmp2['dis'] != 1, 'dis'].max())
tmp_min.append(tmp2.loc[tmp2['dis'] != 1, 'dis'].min())

tmp_max.append(tmp2.loc[tmp2['rad'] != 1, 'rad'].max())
tmp_min.append(tmp2.loc[tmp2['rad'] != 1, 'rad'].min())

tmp_max.append(tmp2.loc[tmp2['tax'] != 1, 'tax'].max())
tmp_min.append(tmp2.loc[tmp2['tax'] != 1, 'tax'].min())

tmp_max.append(tmp2.loc[tmp2['ptratio'] != 1, 'ptratio'].max())
tmp_min.append(tmp2.loc[tmp2['ptratio'] != 1, 'ptratio'].min())

tmp_max.append(tmp2.loc[tmp2['lstat'] != 1, 'lstat'].max())
tmp_min.append(tmp2.loc[tmp2['lstat'] != 1, 'lstat'].min())

tmp_max.append(tmp2.loc[tmp2['medv'] != 1, 'medv'].max())
tmp_min.append(tmp2.loc[tmp2['medv'] != 1, 'medv'].min())

print(max(tmp_max))
print(min(tmp_min))

tmp_max2.append(max(tmp_max))
tmp_min2.append(min(tmp_min))

for i in range(tmp2.shape[0]):
    for key, value in tmp2.items():
        if value[i] in tmp_max2:
            print(tmp2.index[i], key)

for i in range(tmp2.shape[0]):
    for key, value in tmp2.items():            
        if value[i] in tmp_min2:
            print(tmp2.index[i], key)
# Out:
# 0.9102281885331865
# 0.00736824088607757
# rad tax
# tax rad
# chas rad
# rad chas

# %%
tmp2 = tmp.abs()

tmp_max_num, tmp_max_index_i, tmp_max_index_j = 0, 0, 0
tmp_min_num, tmp_min_index_i, tmp_min_index_j = tmp2.iat[0,0], 0, 0

for i in range(tmp2.shape[0]):
    for j in range(tmp2.shape[1]):
        if tmp2.iat[i, j] > tmp_max_num and tmp2.iat[i, j] != 1:
            tmp_max_num = tmp2.iat[i, j]
            tmp_max_index_i = i
            tmp_max_index_j = j

    for j in range(tmp2.shape[1]):
        if tmp2.iat[i, j] < tmp_min_num and tmp2.iat[i, j] != 1:
            tmp_min_num = tmp2.iat[i, j]
            tmp_min_index_i = i
            tmp_min_index_j = j
            
print(f'최대 상관 계수: {round(tmp_max_num, 4)}, 관계 요인: {tmp2.index[tmp_max_index_i]}, {tmp2.index[tmp_max_index_j]}')
print(f'최소 상관 계수: {round(tmp_min_num, 4)}, 관계 요인: {tmp2.index[tmp_min_index_i]}, {tmp2.index[tmp_min_index_j]}')
# Out:
# 최대 상관 계수: 0.9102, 관계 요인: rad, tax
# 최소 상관 계수: 0.0074, 관계 요인: chas, rad
