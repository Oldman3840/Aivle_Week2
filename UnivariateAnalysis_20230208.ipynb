# %% [markdown]
# # 단변량분석_숫자형변수

# %% [markdown]
# <img src='https://github.com/DA4BAM/image/blob/main/%EB%8B%A8%EB%B3%80%EB%9F%89%EB%B6%84%EC%84%9D.png?raw=true' width=400/>

# %% [markdown]
# # 1.환경준비

# %% [markdown]
# ## (1) 라이브러리 불러오기

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## (2) 데이터 로딩

# %% [markdown]
# ### 1) titanic
# * url :  'https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic_simple.csv'

# %% [markdown]
# **[titanic_simple 데이터 셋 정보]**
#
# - PassengerId : 승객번호
# - Survived : 생존여부(1:생존, 0:사망)
# - Pclass : 객실등급(1:1등급, 2:2등급, 3:3등급)
# - Name : 승객이름
# - Sex : 성별(male, female)
# - Age : 나이
# - Fare : 운임($)
# - Embarked : 승선지역(Southhampton, Cherbourg, Queenstown)

# %%
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic_simple.csv'
titanic = pd.read_csv(path)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age     Fare  \
# 0                            Braund, Mr. Owen Harris    male  22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                             Heikkinen, Miss. Laina  female  26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                           Allen, Mr. William Henry    male  35.0   8.0500
#
#        Embarked
# 0  Southhampton
# 1     Cherbourg
# 2  Southhampton
# 3  Southhampton
# 4  Southhampton

# %% [markdown]
# ### 2) New York Air Quality
#
# * url : https://raw.githubusercontent.com/DA4BAM/dataset/master/air2.csv

# %% [markdown]
# **[airquality 데이터 셋 정보]**
#
# - Ozone: 오존 농도
# - Solar.R: 태양복사량
# - Wind: 풍속
# - Temp: 기온
# - Date : 연,월,일

# %%
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/air2.csv'
air = pd.read_csv(path)
air.head()
# Out:
#    Ozone  Solar.R  Wind  Temp        Date
# 0     41    190.0   7.4    67  1973-05-01
# 1     36    118.0   8.0    72  1973-05-02
# 2     12    149.0  12.6    74  1973-05-03
# 3     18    313.0  11.5    62  1973-05-04
# 4     19      NaN  14.3    56  1973-05-05

# %% [markdown]
# # 2.숫자형 변수

# %% [markdown]
# ## (1) 수치화 : 대푯값

# %% [markdown]
# ### 1) 평균(산술평균)

# %%
# 넘파이 함수 이용하기
np.mean(titanic['Fare'])
# Out:
# 32.204207968574636

# %%
# 판다스의 mean 메서드 이용하기
titanic['Fare'].mean()
# Out:
# 32.204207968574636

# %% [markdown]
# ### 2) 중앙값(중위수, median)
#
# 자료의 순서상 가운데 위치한 값

# %%
# 넘파이 함수 이용하기
np.median(titanic['Fare'])
# Out:
# 14.4542

# %%
# 판다스의 median 메서드 이용하기
titanic['Fare'].median()
# Out:
# 14.4542

# %% [markdown]
# ### 3) 최빈값
#
# * 자료 중에서 가장 빈번하게 나타나는 값(빈도가 높은 값)
# * 이산형 데이터(셀 수 있는 데이터)

# %%
# 판다스 메서드 이용하기
titanic['Pclass'].mode()
# Out:
# 0    3
# Name: Pclass, dtype: int64

# %% [markdown]
# ### 4) 4분위수

# %% [markdown]
# ![](https://mblogthumb-phinf.pstatic.net/20150702_229/jevida_1435803723327eyeeG_PNG/3.png?type=w2)

# %%
titanic['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# 연습문제를 풀어 봅시다.

# %%
# titanic의 Age에 대해서 다음을 각각 확인해 봅시다.
titanic['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# air의 Ozone에 대해서 다음을 각각 확인해 봅시다.
air['Ozone'].describe()
# Out:
# count    153.000000
# mean      42.052288
# std       30.156127
# min        1.000000
# 25%       20.000000
# 50%       34.000000
# 75%       59.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %% [markdown]
# ## (2) 수치화 : 기초통계량

# %% [markdown]
# ### 1) 시리즈.describe()

# %%
titanic['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# ### 2) 데이터프레임.describe()

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age     Fare  \
# 0                            Braund, Mr. Owen Harris    male  22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                             Heikkinen, Miss. Laina  female  26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                           Allen, Mr. William Henry    male  35.0   8.0500
#
#        Embarked
# 0  Southhampton
# 1     Cherbourg
# 2  Southhampton
# 3  Southhampton
# 4  Southhampton

# %%
# 데이터프레임의 숫자타입 변수들 기초통계량 조회
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age        Fare
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118   32.204208
# std     257.353842    0.486592    0.836071   14.526497   49.693429
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    7.910400
# 50%     446.000000    0.000000    3.000000   28.000000   14.454200
# 75%     668.500000    1.000000    3.000000   38.000000   31.000000
# max     891.000000    1.000000    3.000000   80.000000  512.329200

# %%
# 데이터프레임의 전체 변수들 기초통계량 조회
titanic.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#                Age        Fare      Embarked
# ...

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# air 데이터프레임에 대해서 기초 통계량을 구하고, 내용을 파악해 봅시다.

# %%
air.describe()
# Out:
#             Ozone     Solar.R        Wind        Temp
# count  153.000000  146.000000  153.000000  153.000000
# mean    42.052288  185.931507    9.957516   77.882353
# std     30.156127   90.058422    3.523001    9.465270
# min      1.000000    7.000000    1.700000   56.000000
# 25%     20.000000  115.750000    7.400000   72.000000
# 50%     34.000000  205.000000    9.700000   79.000000
# 75%     59.000000  258.750000   11.500000   85.000000
# max    168.000000  334.000000   20.700000   97.000000

# %% [markdown]
# ## (3) 시각화

# %% [markdown]
# ### 1) 히스토그램

# %% [markdown]
# * 히스토그램 기본

# %%
plt.hist(titanic.Fare, bins = 5, edgecolor = 'red')
# plt.hist(titanic['Fare'], bins = 5, edgecolor = 'gray')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# * 구간의 갯수를 조정해 봅시다.

# %%
plt.hist(titanic.Fare, bins = 100, edgecolor = 'red')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()

plt.hist(titanic.Fare, bins = 100, edgecolor = 'red')
plt.xlim(0, 100)
plt.show()

# %% [markdown]
# * sns.histplot

# %%
sns.histplot(x= 'Fare', data = titanic, bins = 20)
plt.show()

# %% [markdown]
# * (추가)구간 값과 갯수를 확인해 봅시다.
#
#     * 결과를 저장하면, 구간과 빈도수를 확인할 수 있습니다.
#         * 히스토그램을 저장하면 튜플.
#         * 튜플 안에는 넘파이 어레이가 2개로 구성됨.
#         * 첫번째 넘파이 어레이는 빈도수,
#         * 두번째는 구간 값.

# %%
hist1 = plt.hist(titanic.Fare, bins = 5, edgecolor = 'gray')
plt.show()

print(hist1)
print(type(hist1))
print('-' * 50)
print('빈도수 : ', hist1[0])
print('구간값 : ', hist1[1])

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# [문제1] titanic의 Age에 칼럼에 대해 히스토그램을 그려 봅시다.
# * bins = 8, 16, 32, 64

# %%
plt.subplot(2,2,1)
plt.hist(titanic['Age'], bins = 8, edgecolor = 'red')
plt.subplot(2,2,2)
plt.hist(titanic['Age'], bins = 16, edgecolor = 'red')
plt.subplot(2,2,3)
plt.hist(titanic['Age'], bins = 32, edgecolor = 'red')
plt.subplot(2,2,4)
plt.hist(titanic['Age'], bins = 64, edgecolor = 'red')

plt.show()

# %% [markdown]
# [문제2] (추가) Age에 칼럼에 대해 히스토그램을 그릴때, 빈도수와 구간값을 살펴 봅시다.
# * bins = 8

# %% [markdown]
# ### 2) 밀도함수 그래프(kde plot)

# %% [markdown]
# * 히스토그램의 단점
#     * 구간(bin)의 너비를 어떻게 잡는지에 따라 전혀 다른 모양이 될 수 있음
#
# * 밀도함수 그래프
#     * 막대의 너비를 가정하지 않고 모든 점에서 데이터의 밀도를 추정하는 커널 밀도 추정(Kernel Density Estimation)방식을 사용하여 이러한 단점을 해결.
#     * 밀도함수 그래프 아래 면적은 1

# %% [markdown]
# * 밀도함수 그래프 그리기

# %%
sns.kdeplot(titanic['Fare'])
# sns.kdeplot(x='Fare', data = titanic)

plt.show()

# %% [markdown]
# * 밀도 추정
#     * 측정된(관측된) 데이터로부터 전체 데이터 분포의 특성을 추정
#     * 예를 들어… OO역 사거리 일일 교통량을 측정한다고 해 봅시다.
#         * 어제는 1200대 차량이 통과했고, 오늘은 1420대, 내일은, 모레는…
#         * 이렇게 3개월간 매일 측정했다고 할 때,
#         * 우리는 약 90일치의 데이터를 가지고 일일 교통량 분포를 히스토그램으로 그려볼 수 있습니다.
#         * 그리고 나서 특정한 날의 교통량이 얼마나 될지 확률로 나타냄.

# %% [markdown]
# <img src='https://github.com/DA4BAM/image/blob/main/%EB%B0%80%EB%8F%84%EC%B6%94%EC%A0%95.png?raw=true' width=800/>

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# [문1] titanic Age에 대해서 밀도함수 그래프를 그려봅시다.
#
# 히스토그램과 어떤 차이가 있나요?

# %%
# sns.kdeplot(titanic['Age'])
sns.kdeplot(x = 'Age', data = titanic)
plt.show()

# %% [markdown]
# [문2] titanic Age에 대해서 히스토그램을 그려봅시다.
# * 단, 이번에는 sns.histplot 을 이용합니다.
# * 옵션으로 kde = True 를 지정해 봅시다.

# %%
# sns.histplot(titanic['Age'], kde = True)
sns.histplot(x = 'Age', data = titanic, kde = True)
plt.show()

# %% [markdown]
# ### 3) boxplot
#
# **주의사항** : 값에 **NaN**이 있으면 그래프가 그려지지 않습니다.

# %% [markdown]
# * boxplot 기본

# %%
# titanic['Age']에는 NaN이 있습니다. 이를 제외한 데이터
temp = titanic.loc[titanic['Age'].notnull()]

# %%
plt.boxplot(temp['Age'])
plt.grid()
plt.show()

# %% [markdown]
# * 옆으로 그리기

# %%
plt.boxplot(temp['Age'], vert = False)
plt.grid()
plt.show()

# %% [markdown]
# * sns.boxplot
#     * seaborn 패키지 함수들은 NaN을 알아서 빼줍니다.

# %%
sns.boxplot(x = titanic['Age'])
plt.grid()
plt.show()

# %%
sns.boxplot(y = titanic['Age'])
plt.grid()
plt.show()

# %% [markdown]
# **박스플롯의 의미**

# %% [markdown]
# <img src='https://github.com/DA4BAM/image/blob/main/%EB%B0%95%EC%8A%A4%ED%94%8C%EB%A1%AF1.png?raw=true' width=600/>

# %% [markdown]
# <img src='https://github.com/DA4BAM/image/blob/main/%EB%B0%95%EC%8A%A4%ED%94%8C%EB%A1%AF2.png?raw=true' width=800/>

# %% [markdown]
# * (추가) 박스플롯의 값들 가져오기

# %%
age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
box1 = plt.boxplot(age)
plt.show()

print(type(box1))
print(box1.keys())
print('-'* 50)
print(box1['whiskers'])
print(box1['whiskers'][0].get_ydata()) # 아래쪽 수염의 max, min
print(box1['whiskers'][1].get_ydata()) # 위쪽 수염의 min, max

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# [문1] titanic의 Age와 Fare에 대해서 각각 박스 플롯을 그리고 해석해 봅시다.

# %%
plt.figure(figsize = (12, 2))
sns.boxplot(x = 'Fare', data = titanic)
plt.grid()
plt.show()

# %% [markdown]
#     box plot특징: 지불한 요금의 결과가 한쪽에 몰려 있다.

# %% [markdown]
# [문2] Age : boxplot의 수염(whiskers)의 길이를 손으로 계산해 봅시다.

# %% [markdown]
# ### 4) 시계열 데이터 시각화

# %% [markdown]
# * 시계열 데이터는 보통 시간 축(x축)에 맞게 값들을 라인차트로 표현합니다.

# %%
air['Date'] = pd.to_datetime(air['Date']) # 날짜 형식으로 변환

plt.plot('Date', 'Ozone', 'g-', data = air, label = 'Ozone')
plt.plot('Date', 'Temp', 'r-', data = air, label = 'Temp')

plt.xlabel('Date')
plt.legend()

# %%
air.head()
# Out:
#    Ozone  Solar.R  Wind  Temp       Date
# 0     41    190.0   7.4    67 1973-05-01
# 1     36    118.0   8.0    72 1973-05-02
# 2     12    149.0  12.6    74 1973-05-03
# 3     18    313.0  11.5    62 1973-05-04
# 4     19      NaN  14.3    56 1973-05-05

# %% [markdown]
# # 3.범주형 변수

# %% [markdown]
# ## (1) 수치화 : 기초통계량

# %% [markdown]
# * 범주형 변수는 범주별 빈도수와 비율을 확인합니다.
# * 리스트.count(‘값’)
#     * 해당 값이 몇 개 있는지 count 해 줍니다.
#     * Count를 전체 개수(len(gender))로 나눠주면 비율이 됩니다.
#     * 그런데, 범주가 두 세 개 정도면, 이렇게 계산하는 게 가능합니다.
#     * 만약 범주가 10개라면?

# %% [markdown]
# ### 1) 범주별 빈도수
# * .value_counts() : 범주의 개수와 상관 없이 범주 별 개수를 count 해 줍니다.

# %%
titanic['Embarked'].value_counts()
# Out:
# Southhampton    644
# Cherbourg       168
# Queenstown       77
# Name: Embarked, dtype: int64

# %% [markdown]
# ### 2) 범주별 비율
# * .value_counts()를 전체 데이터 건수로 나눠줍니다.

# %%
# 전체 데이터 건수 : .shape의 첫번째 값([0])
print(titanic.shape)
print(titanic.shape[0])
# Out:
# (891, 8)
# 891

# %% [markdown]
# 데이터프레임의 행, 열의 수를 세는 다양한 방법 : https://rfriend.tistory.com/450

# %%
titanic['Pclass'].value_counts()/titanic.shape[0]
# Out:
# 3    0.551066
# 1    0.242424
# 2    0.206510
# Name: Pclass, dtype: float64

# %% [markdown]
# * titanic['Pclass’] 해석
#     * .value_counts()를 이용하여 범주별 빈도수와 범주별 비율을 구할수 있습니다.
#     * 3등급 객실 탑승객이 전체에서 55%를 차지합니다.
#     * 1등급 객실이 24%, 2등급 객실이 20.7 %

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# [문1] titanic의 Embarked에 대한 기초 통계량을 구하시오.

# %%
print(titanic['Embarked'].value_counts())

print(titanic['Embarked'].value_counts() / titanic.shape[0])

# sns.countplot(titanic['Embarked'], hue = True)
# plt.show()
# Out:
# Southhampton    644
# Cherbourg       168
# Queenstown       77
# Name: Embarked, dtype: int64
# Southhampton    0.722783
# Cherbourg       0.188552
# Queenstown      0.086420
# Name: Embarked, dtype: float64

# %% [markdown]
# [문2] titanic의 Survived에 대한 기초 통계량을 구하시오.

# %%
print(titanic['Survived'].value_counts())

print(titanic['Survived'].value_counts() / titanic.shape[0])
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %%
display(pd.Categorical(titanic['Survived']).describe())
display(pd.Categorical(titanic['Sex']).describe())
display(pd.Categorical(titanic['Embarked']).describe())
# Out:
#             counts     freqs
# categories
# 0              549  0.616162
# 1              342  0.383838
#             counts     freqs
# categories
# female         314  0.352413
# male           577  0.647587
#               counts     freqs
# categories
# Cherbourg        168  0.188552
# Queenstown        77  0.086420
# Southhampton     644  0.722783
# NaN                2  0.002245

# %% [markdown]
# ## (2) 시각화

# %% [markdown]
# ### 1) bar chart

# %% [markdown]
# * seaborn의 countplot
#     * plt.bar() 를 이용하려면 먼저 집계한 후 결과를 가지고 그래프를 그려야 합니다.
#     * countplot은 집계 + bar plot을 한꺼번에 해결해줍니다!

# %%
sns.countplot(x = titanic['Pclass'])
plt.grid()
plt.show()

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# [문1] titanic의 Embarked에 대한 bar chart를 그리시오.

# %%
sns.countplot(x = titanic['Embarked'], orient="h")
plt.grid()
plt.show()

# %%
tmp = titanic['Embarked'].value_counts()
print(tmp.index, tmp.values)
# Out:
# Index(['Southhampton', 'Cherbourg', 'Queenstown'], dtype='object') [644 168  77]

# %% [markdown]
# ### 2) (추가) pie chart

# %% [markdown]
# * 범주별 비율 비교할 때 파이차트 사용.
# * 역시 먼저 집계를 해야 합니다.
# * plt.pie( 값, labels=범주이름, autopct = ‘%.2f%%’)
#     * autopct = ‘%**.2f%**%’ : 그래프에 표시할 값 비율 값에 대한 설정입니다.
#         * **.2f%** : 소수점 두 자리 퍼센트로 표기 한다는 의미.

# %% [markdown]
# * pie chart 기본

# %%
temp = titanic['Pclass'].value_counts()

plt.pie(temp.values, labels = temp.index, autopct = '%.2f%%')
plt.show()

# %% [markdown]
# * pie chart 꾸미기 1
#
#     * 각도와 방향 조정
#         * startangle = 90 : 90도 부터 시작
#         * counterclock = False : 시계 방향으로

# %%
plt.pie(temp.values, labels = temp.index, autopct = '%.2f%%', 
        startangle=90, counterclock=False)
plt.show()

# %% [markdown]
# * pie chart 꾸미기 2
#
#     * 간격 띄우고, 그림자 넣기
#         * explode = [0.05, 0.05,0.05] : 중심으로 부터 1,2,3 을 얼마만큼 띄울지
#         * shadow = True : 그림자 추가

# %%
plt.pie(temp.values, labels = temp.index, autopct = '%.2f%%', 
        startangle=90, counterclock=False, 
        explode = [0.05, 0.05, 0.05], shadow=True)
plt.show()

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# 1) titanic의 Embarked에 대한 pie chart를 그리시오.
# * 소수점 1자리까지 비율(%)를 표시하시오.

# %%
tmp = titanic['Embarked'].value_counts()

plt.pie(tmp.values, labels = temp.index, autopct = '%.1f%%')
plt.show()

# %% [markdown]
# # 4.복습문제

# %% [markdown]
# ## (1) 환경준비
# * 라이브러리 불러오기

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * 보스톤 집값 데이터를 이용하여 다음의 복습문제를 풀어 봅시다.

# %% [markdown]
# **변수설명**
# > * medv  : 1978 보스턴 주택 가격, 506개 타운의 주택 가격 중앙값 (단위 1,000 달러) <== Target
# * crim	범죄율
# * zn	25,000 평방피트를 초과 거주지역 비율
# * indus	비소매상업지역 면적 비율
# * chas	찰스강변 위치(범주 : 강변1, 아니면 0)
# * nox	일산화질소 농도
# * rm	주택당 방 수
# * age	1940년 이전에 건축된 주택의 비율
# * dis	직업센터의 거리
# * rad	방사형 고속도로까지의 거리
# * tax	재산세율
# * ptratio	학생/교사 비율
# * lstat	인구 중 하위 계층 비율

# %%
# 보스톤 집값 데이터
boston = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/boston.csv')
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %% [markdown]
# ## (2) 단변량 분석

# %% [markdown]
# ### 1) 숫자형 변수

# %% [markdown]
# * medv(집값)

# %%
var = 'medv'

# %%
# 기초통계량
boston[[var]].describe().T
# Out:
#       count       mean       std  min     25%   50%   75%   max
# medv  506.0  22.532806  9.197104  5.0  17.025  21.2  25.0  50.0

# %%
# 시각화
plt.figure(figsize=(6, 4))

plt.subplot(2,1,1)
sns.histplot(x = boston[var], bins = 20, kde = True)
plt.subplot(2,1,2)
plt.boxplot(boston[var], vert = False)
plt.grid()
plt.show()

# %%
def eda1_n(data, var, bins = 20, kde = True):
    
    display(data[[var]].describe().T)

    plt.figure(figsize=(6, 4))

    plt.subplot(2,1,1)
    sns.histplot(x = data[var], bins = bins, kde = kde)
    plt.grid()
    
    plt.subplot(2,1,2)
    # plt.boxplot(boston[var], vert = False)
    sns.boxplot(x = var, data = data)
    plt.grid()
    plt.show()

# %%
# 보스턴 시 타운별 집값 중앙값
eda1_n(boston, 'medv', 50, True)

# 50 부근에서 그래프가 튄다.
# 이 내용에 대해서 수많은 추측이 있지만, 현장의 상황을 파악해서 원인에 대해서 찾아봐야 한다.
# Out:
#       count       mean       std  min     25%   50%   75%   max
# medv  506.0  22.532806  9.197104  5.0  17.025  21.2  25.0  50.0

# %% [markdown]
# * crim(범죄율)

# %%
vars = 'crim'
eda1_n(boston, vars, 50)
# Out:
#       count      mean       std      min       25%      50%       75%      max
# crim  506.0  3.613524  8.601545  0.00632  0.082045  0.25651  3.677083  88.9762

# %%
# 기초통계량
print(boston['crim'].describe())
# Out:
# count    506.000000
# mean       3.613524
# std        8.601545
# min        0.006320
# 25%        0.082045
# 50%        0.256510
# 75%        3.677083
# max       88.976200
# Name: crim, dtype: float64

# %%
# 시각화
plt.figure(figsize=(6,2))

# plt.subplot(2,1,1)
sns.histplot(x = boston['crim'], bins=20, kde=True)
# plt.subplot(2,1,2)
# plt.boxplot(boston['crim'], vert=False)
plt.grid()
plt.show()

# %% [markdown]
# * lstat(하위계층 비율)

# %%
# 기초통계량
print(boston['lstat'].describe())
# Out:
# count    506.000000
# mean      12.653063
# std        7.141062
# min        1.730000
# 25%        6.950000
# 50%       11.360000
# 75%       16.955000
# max       37.970000
# Name: lstat, dtype: float64

# %%
# 시각화
plt.figure(figsize=(6,2))

# plt.subplot(2,1,1)
sns.histplot(x = boston['lstat'], bins=20, kde=True)
# plt.subplot(2,1,2)
# plt.boxplot(boston['crim'], vert=False)
plt.grid()
plt.show()

# %% [markdown]
# * ptratio(교사1명당 학생수)

# %%
eda1_n(boston, 'ptratio', 50)
# Out:
#          count       mean       std   min   25%    50%   75%   max
# ptratio  506.0  18.455534  2.164946  12.6  17.4  19.05  20.2  22.0

# %%
# 기초통계량
print(boston['ptratio'].describe())
# Out:
# count    506.000000
# mean      18.455534
# std        2.164946
# min       12.600000
# 25%       17.400000
# 50%       19.050000
# 75%       20.200000
# max       22.000000
# Name: ptratio, dtype: float64

# %%
# 시각화
plt.figure(figsize=(6,2))

# plt.subplot(2,1,1)
sns.histplot(x = boston['ptratio'], bins=20, kde=True)
# plt.subplot(2,1,2)
# plt.boxplot(boston['crim'], vert=False)
plt.grid()
plt.show()

# %% [markdown]
# ### 2) 범주형 변수

# %% [markdown]
# * chas(찰스강변 여부)

# %%
# Out:
# 0    471
# 1     35
# Name: chas, dtype: int64
# 0    0.93083
# 1    0.06917
# Name: chas, dtype: float64

# %%
# 기초통계량
print(boston['chas'].value_counts())
print(boston['chas'].value_counts() / boston.shape[0])
# Out:
# 0    471
# 1     35
# Name: chas, dtype: int64
# 0    0.93083
# 1    0.06917
# Name: chas, dtype: float64

# %%
# 시각화
sns.countplot(x = boston['chas'], data = boston)
plt.grid()
plt.show()
