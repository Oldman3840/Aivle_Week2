# %% [markdown]
# # 종합실습3 이변량분석(y-범주) : 직원 이직 분석

# %% [markdown]
# ![](https://www.talentalign.com/wp-content/uploads/2019/09/main-qimg-2434943004743f79c0abf540cb4f6e2c-cropped.jpg)

# %% [markdown]
# * 직원 이직 분석
#     * 회사에서 최근 1~2년 사이 이직률이 상승하였습니다.
#     * 여러분은, 직원들이 이직하는데 중요한 요인이 무엇인지 데이터를 기반으로 한 분석을 의뢰 받았습니다.

# %% [markdown]
# # 1.환경준비

# %% [markdown]
# * 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.mosaicplot import mosaic      #mosaic plot!

import scipy.stats as spst

# %% [markdown]
# * 데이터 불러오기 : 다음의 예제 데이터를 사용합니다.

# %%
# 직원 이직 데이터
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/Attrition_simple2.CSV'
data = pd.read_csv(path)  
data.head(5)
# Out:
#    Attrition  Age  DistanceFromHome  EmployeeNumber  Gender  JobSatisfaction  \
# 0          0   33                 7             817    Male                3
# 1          0   35                18            1412    Male                4
# 2          0   42                 6            1911    Male                1
# 3          0   46                 2            1204  Female                1
# 4          1   22                 4             593    Male                3
#
#   MaritalStatus  MonthlyIncome OverTime  PercentSalaryHike  TotalWorkingYears
# 0       Married          11691       No                 11                 14
# 1        Single           9362       No                 11                 10
# 2       Married          13348       No                 13                 18
# 3       Married          17048       No                 23                 28
# 4        Single           3894       No                 16                  4

# %% [markdown]
# > * 변수설명
#     * Attrition	:	이직여부, Yes , No (Target)
#     * Age	:	나이
#     * DistanceFromHome	:	집-직장 거리(마일)
#     * EmployeeNumber	:	사번
#     * Gender	:	성별(Male, Female)
#     * JobSatisfaction	:	직무 만족도, 다음시트 참조
#     * MaritalStatus	:	결혼상태(Married, Single, Divorced)
#     * MonthlyIncome	:	월급(달러)
#     * OverTime	:	야근여부
#     * PercentSalaryHike	:	전년대비 급여인상율(%)
#     * TotalWorkingYears	:	총 근무 연수

# %% [markdown]
# # 2.범주-->범주

# %%
target = 'Attrition'

# %% [markdown]
# ## (1) Gender --> Attrition

# %%
feature = 'Gender'

# %% [markdown]
# * 교차표

# %%
# 두 범주별 빈도수를 교차표로 만들어 봅시다.
pd.crosstab(data[target], data[feature])
# Out:
# Gender     Female  Male
# Attrition
# 0             403   598
# 1              66   129

# %%
pd.crosstab(data[target], data[feature], normalize = 'columns')
# Out:
# Gender       Female      Male
# Attrition
# 0          0.859275  0.822558
# 1          0.140725  0.177442

# %% [markdown]
# * 시각화

# %%
mosaic(data, [ feature,target])
plt.axhline(1- data[target].mean(), color = 'r')
plt.show()

# %% [markdown]
# * 수치화 : 카이제곱검정

# %%
# 먼저 집계
table = pd.crosstab(data[target], data[feature])
print('교차표\n', table)
print('-' * 100)

# 카이제곱검정
result = spst.chi2_contingency(table)
print('카이제곱통계량', result[0])
print('p-value', result[1])
print('기대빈도\n',result[3])
# Out:
# 교차표
#  Gender     Female  Male
# Attrition
# 0             403   598
# 1              66   129
# ----------------------------------------------------------------------------------------------------
# 카이제곱통계량 2.5537631338119975
# p-value 0.1100318964829815
# 기대빈도
#  [[392.5326087 608.4673913]
#  [ 76.4673913 118.5326087]]

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
#     관련이 적어보이지만, 도메인지식을 활용한 비즈니스적 관점에서 보면 관련있는 데이터로 보일 수 있다.

# %% [markdown]
# ## (2) JobSatisfaction --> Attrition

# %%
target = 'Attrition'

# %% [markdown]
# * 교차표

# %%
feature = 'JobSatisfaction'
display(pd.crosstab(data[target], data[feature]))
display(pd.crosstab(data[target], data[feature], normalize = 'columns'))
# Out:
# JobSatisfaction    1    2    3    4
# Attrition
# 0                191  189  295  326
# 1                 52   37   59   47
# JobSatisfaction         1         2         3         4
# Attrition
# 0                0.786008  0.836283  0.833333  0.873995
# 1                0.213992  0.163717  0.166667  0.126005

# %% [markdown]
# * 시각화

# %%
mosaic(data, [feature, target])
plt.axhline(1- data[target].mean(), color = 'y')
plt.show()

# %% [markdown]
# * 수치화 : 카이제곱검정

# %%
table = pd.crosstab(data[target], data[feature])
print('교차표\n', table)
print('-' * 100)

# 카이제곱검정
result = spst.chi2_contingency(table)
print('카이제곱통계량', result[0])
print('p-value', result[1])
print('dot', result[2])
print('기대빈도\n',result[3])
# Out:
# 교차표
#  JobSatisfaction    1    2    3    4
# Attrition
# 0                191  189  295  326
# 1                 52   37   59   47
# ----------------------------------------------------------------------------------------------------
# 카이제곱통계량 8.40684948576828
# p-value 0.0383107376547955
# dot 3
# 기대빈도
#  [[203.38043478 189.15217391 296.2826087  312.18478261]
#  [ 39.61956522  36.84782609  57.7173913   60.81521739]]

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
#     관련이 있어 보이지만, 수치(p_value) 상 큰 차이가 있는 것은 아니다

# %% [markdown]
# ## (3) MaritalStatus --> Attrition

# %%
target = 'Attrition'

# %% [markdown]
# * 교차표

# %%
feature = 'MaritalStatus'
display(pd.crosstab(data[target], data[feature]))
display(pd.crosstab(data[target], data[feature], normalize = 'columns'))
# Out:
# MaritalStatus  Divorced  Married  Single
# Attrition
# 0                   241      479     281
# 1                    23       69     103
# MaritalStatus  Divorced   Married    Single
# Attrition
# 0              0.912879  0.874088  0.731771
# 1              0.087121  0.125912  0.268229

# %% [markdown]
# * 시각화

# %%
mosaic(data, [feature, target])
plt.axhline(1- data[target].mean(), color = 'y')
plt.show()

# %% [markdown]
# * 수치화 : 카이제곱검정

# %%
table = pd.crosstab(data[target], data[feature])
print('교차표\n', table)
print('-' * 100)

# 카이제곱검정
result = spst.chi2_contingency(table)
print('카이제곱통계량', result[0])
print('p-value', result[1])
print('dot', result[2])
print('기대빈도\n',result[3])
# Out:
# 교차표
#  MaritalStatus  Divorced  Married  Single
# Attrition
# 0                   241      479     281
# 1                    23       69     103
# ----------------------------------------------------------------------------------------------------
# 카이제곱통계량 47.82247929575401
# p-value 4.12553775054082e-11
# dot 2
# 기대빈도
#  [[220.95652174 458.65217391 321.39130435]
#  [ 43.04347826  89.34782609  62.60869565]]

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
#     결혼 여부와 이직 빈도는 상당한 관계가 있다.

# %% [markdown]
# ## (4) OverTime --> Attrition

# %%
target = 'Attrition'
feature = 'OverTime'

# %% [markdown]
# * 교차표

# %%
display(pd.crosstab(data[target], data[feature]))
display(pd.crosstab(data[target], data[feature], normalize = 'columns'))
# Out:
# OverTime    No  Yes
# Attrition
# 0          764  237
# 1           90  105
# OverTime         No       Yes
# Attrition
# 0          0.894614  0.692982
# 1          0.105386  0.307018

# %% [markdown]
# * 시각화

# %%
mosaic(data, [feature, target])
plt.axhline(1- data[target].mean(), color = 'y')
plt.show()

# %% [markdown]
# * 수치화 : 카이제곱검정

# %%
table = pd.crosstab(data[target], data[feature])
print('교차표\n', table)
print('-' * 100)

# 카이제곱검정
result = spst.chi2_contingency(table)
print('카이제곱통계량', result[0])
print('p-value', result[1])
print('dot', result[2])
print('기대빈도\n',result[3])
# Out:
# 교차표
#  OverTime    No  Yes
# Attrition
# 0          764  237
# 1           90  105
# ----------------------------------------------------------------------------------------------------
# 카이제곱통계량 71.28471646317081
# p-value 3.092218315896121e-17
# dot 1
# 기대빈도
#  [[714.76086957 286.23913043]
#  [139.23913043  55.76086957]]

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
#     야근 여부와 이직 여부는 관계가 있다.

# %% [markdown]
# # 3.숫자-->범주

# %% [markdown]
# ## (1) Age --> Attrition

# %%
feature = 'Age'

# %%
sns.kdeplot(x= feature, data = data, hue = target, 
            common_norm = False)
plt.show()

# %%
sns.kdeplot(x= feature, data = data, hue = target
            , multiple = 'fill')
plt.axhline(data[target].mean(), color = 'r')
plt.show()

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
# ## (2) DistanceFromHome --> Attrition

# %%
target = 'Attrition'
feature = 'DistanceFromHome'

# %%
plt.subplot(2, 1, 1)
sns.kdeplot(x= feature, data = data, hue = target, 
            common_norm = False)
plt.subplot(2, 1, 2)
sns.kdeplot(x= feature, data = data, hue = target
            , multiple = 'fill')
plt.axhline(data[target].mean(), color = 'r')

plt.show()

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
#     직장과 집의 거리가 이직 여부와 관련이 있다.
#     집이 10km 이하인 사람들은 이직 빈도가 평균 이하이고,
#     그 이상인 사람들은 이직 빈도가 평균 이상이다.

# %% [markdown]
# ## (3) MonthlyIncome --> Attrition

# %%
target = 'Attrition'
feature = 'MonthlyIncome'

# %%
plt.subplot(2, 1, 1)
sns.kdeplot(x= feature, data = data, hue = target, 
            common_norm = False)
plt.subplot(2, 1, 2)
sns.kdeplot(x= feature, data = data, hue = target
            , multiple = 'fill')
plt.axhline(data[target].mean(), color = 'r')

plt.tight_layout()
plt.show()

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
#     월급 평균과 이직 빈도의 차이는 있다.
#     월급 평균 10000달러 이상인 경우, 이직 빈도가 낮다.

# %% [markdown]
# ## (4) PercentSalaryHike --> Attrition

# %%
target = 'Attrition'
feature = 'PercentSalaryHike'

# %%
plt.subplot(2, 1, 1)
sns.kdeplot(x= feature, data = data, hue = target, 
            common_norm = False)
plt.subplot(2, 1, 2)
sns.kdeplot(x= feature, data = data, hue = target
            , multiple = 'fill')
plt.axhline(data[target].mean(), color = 'r')

plt.tight_layout()
plt.show()

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
#     두 데이터는 전체 평균과 유사한 선을 그리므로, 둘 사이에 관계는 크지 않다.
#     임금인상률이 낮은데 이직하지 않은 사람의 상황을 더 들여다 봐야한다.
#     (ex: 고액연봉자 일 수도)

# %% [markdown]
# ## (5) TotalWorkingYears --> Attrition

# %%
target = 'Attrition'
feature = 'TotalWorkingYears'

# %%
plt.subplot(2, 1, 1)
sns.kdeplot(x= feature, data = data, hue = target, 
            common_norm = False)
plt.subplot(2, 1, 2)
sns.kdeplot(x= feature, data = data, hue = target
            , multiple = 'fill')
plt.axhline(data[target].mean(), color = 'r')

plt.tight_layout()
plt.show()

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
#     근속년수와 이직 여부와 관계가 있다.
#     근속년수가 10년 이상인 시점부터 지속적으로 이직 빈도가 줄어든다.

# %% [markdown]
# # 4.관계 정리하기

# %% [markdown]
# ① 강한관계

# %% [markdown]
#     MaritalStatus
#     OverTime
#     Age
#     DistanceFromHome
#     MonthlyIncome
#     TotalWorkingyear

# %% [markdown]
# ② 중간관계

# %% [markdown]
#     JobStisfaction

# %% [markdown]
# ③ 관계없음

# %% [markdown]
#     Sex
#     PercentSalaryHike
